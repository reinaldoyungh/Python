# %% [markdown]
# <a href="https://colab.research.google.com/github/reinaldoyungh/Python/blob/main/IA_LLM_GROQ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q groq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.7/141.7 kB 3.6 MB/s eta 0:00:00

# %%
import os
from google.colab import userdata

os.environ["GROQ_API_KEY"] = userdata.get('GROQ_API_KEY')

# %%
from groq import Groq


client = Groq()
completion = client.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[
      {
        "role": "user",
        "content": "O que é IA?"
      }
    ],
    temperature=1,
    max_completion_tokens=1024,
    top_p=1,
    reasoning_effort="medium",
    stream=True,
    stop=None
)

for chunk in completion:
    print(chunk.choices[0].delta.content or "", end="")
# Out:
# **IA** (Inteligência Artificial) é a área da ciência da computação que busca criar sistemas capazes de executar tarefas que, normalmente, exigem inteligência humana. Essas tarefas incluem:
#
# - **Aprendizado** – aprender padrões a partir de dados e melhorar com a experiência (machine learning, deep learning).
# - **Raciocínio** – resolver problemas, fazer deduções e tomar decisões (lógica, redes bayesianas).
# - **Percepção** – reconhecer imagens, sons ou textos (visão computacional, processamento de linguagem natural).
# - **Interação** – conversar, compreender emoções ou se adaptar a usuários (chatbots, assistentes virtuais).
#
# A IA pode ser **estreita** (focada em uma tarefa específica, como reconhecimento de voz) ou **generativa** (capaz de desempenhar múltiplas funções, ainda em desenvolvimento). Em resumo, IA é a busca por máquinas que pensem e ajam de forma inteligente, ajudando a automatizar processos, analisar grandes volumes de dados e melhorar a qualidade de vida.
