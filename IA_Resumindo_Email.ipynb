# %% [markdown]
# <a href="https://colab.research.google.com/github/reinaldoyungh/Python/blob/main/IA_Resumindo_Email.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Desafio:
#
# 1. Pedir pra uma IA gerar em Python uma lista de 20 emails pra você.
#
# 2. Criar uma função que vai receber como argumento/parâmetro uma lista de emails, percorrer essa lista de emails, e, para cada email da lista, ela irá chamar a IA do Gemini via API e pedir pra ela resumir pra você todos os emails em apenas 1 linha, definindo o que essa pessoa queria no email.

# %%
corpos_email = [
    "Olá equipe,\n\nGostaria de agendar nossa reunião de alinhamento para discutir os resultados do último trimestre e planejar os próximos passos. Por favor, confirmem a disponibilidade na agenda compartilhada.",

    "Fala, pessoal!\n\nPara comemorar as metas batidas, vamos nos reunir no bar da esquina nesta sexta às 18h. Quem topa?\n\nAté lá!",

    "Prezados colaboradores,\n\nInformamos que houve uma atualização nas diretrizes de trabalho remoto. O documento em anexo detalha as novas regras que entram em vigor a partir do próximo mês.",

    "Oi Alison,\n\nTudo bem? Só passando para lembrar do livro que te emprestei no mês passado. Já terminou a leitura? Estou precisando dele para uma consulta rápida.",

    "Bom dia,\n\nAnalisei os últimos entregáveis do projeto e gostaria de parabenizar a equipe pela qualidade. Tenho apenas alguns pontos de ajuste que listei no documento compartilhado.",

    "Olá,\n\nSua inscrição para o workshop foi confirmada com sucesso! O evento ocorrerá no dia 20/05 às 14h. Não esqueça de levar seu material de anotação.",

    "Prezados,\n\nGostaria de solicitar um orçamento para a manutenção preventiva dos aparelhos de ar condicionado em minha residência. Fico no aguardo do retorno com valores e datas disponíveis.",

    "Detectamos um novo acesso à sua conta a partir de um dispositivo desconhecido. Se não foi você, recomendamos a alteração imediata da sua senha para garantir sua segurança.",

    "Prezado [Nome],\n\nGostaria de agradecer a oportunidade da entrevista realizada hoje. Fiquei muito entusiasmado com a visão da empresa e espero podermos trabalhar juntos em breve.",

    "Olá,\n\nSou ouvinte assíduo do seu canal e gostaria de sugerir um tema sobre produtividade para os próximos vídeos. Acredito que o público ia adorar o conteúdo!",

    "Aviso importante: O sistema ficará fora do ar para manutenção preventiva neste domingo, entre 02h e 06h da manhã. Planeje suas atividades com antecedência.",

    "O tempo voa! Vou comemorar meu aniversário no sábado que vem e sua presença é fundamental. A festa será na minha casa a partir das 20h. Espero você!",

    "Olá, vi no rastreio que meu pedido está parado no centro de distribuição há alguns dias. Poderiam verificar se há algum problema com a entrega ou com o endereço?",

    "Olá [Nome],\n\nAcompanho seu trabalho há algum tempo e adoramos seu estilo. Gostaria de propor uma parceria para nossa nova campanha. Você teria interesse em conhecer nossa proposta?",

    "Olá, conforme conversamos, seguem em anexo as requisições dos exames solicitados. Por favor, siga as instruções de preparo indicadas no documento.",

    "Suporte,\n\nMinha conexão está oscilando muito desde ontem à noite. Já reiniciei o modem, mas a velocidade continua instável. Podem realizar um teste remoto na linha?",

    "Seja muito bem-vindo, [Nome]! Estamos felizes em ter você no time. Seu acesso ao sistema já foi liberado e o RH passará em breve para te dar as orientações iniciais.",

    "Gostaria de solicitar o cancelamento da minha assinatura mensal. Infelizmente, no momento, não pretendo renovar o serviço. Aguardo a confirmação do procedimento.",

    "Oi,\n\nEstou encaminhando o currículo de um conhecido que é excelente tecnicamente e está buscando novas oportunidades. Acho que ele tem o perfil ideal para a vaga aberta.",

    "Desejamos a todos os nossos clientes e parceiros um excelente ano novo, repleto de conquistas. Que possamos continuar crescendo juntos no próximo ciclo!"
]

# Exemplo de impressão do primeiro corpo
#print(corpos_email[0])

# %%
import google.generativeai as genai

# 1. Configuração da API (Substitua 'SUA_API_KEY_AQUI' pela sua chave real)
genai.configure(api_key="AIzaSyBX-pXzmedSFzlzQtQMsUbPDezCWB0L6Dk")
model = genai.GenerativeModel('gemini-2.5-flash')

def resumir_emails_com_gemini(lista_emails):
    resumos = []

    print(f"Iniciando o processamento de {len(lista_emails)} e-mails...\n")

    for i, corpo in enumerate(lista_emails, 1):
        # Criando o prompt específico para a tarefa
        prompt = f"Resuma o desejo/intenção do remetente deste e-mail em apenas uma linha curta:\n\n{corpo}"

        try:
            # Chamada para a API
            response = model.generate_content(prompt)
            resumo_linha = response.text.strip()

            print(f"E-mail {i} processado com sucesso.")
            resumos.append(resumo_linha)

        except Exception as e:
            print(f"Erro ao processar o e-mail {i}: {e}")
            resumos.append("Erro ao gerar resumo.")

    return resumos

# --- Exemplo de Uso ---

# Supondo que a variável 'corpos_email' (aquela lista de 20) já exista no seu código:
lista_de_resumos = resumir_emails_com_gemini(corpos_email)

print("\n--- RESULTADOS ---")
for r in lista_de_resumos:
    print(f"• {r}")
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)
# Iniciando o processamento de 20 e-mails...
#
# E-mail 1 processado com sucesso.
# E-mail 2 processado com sucesso.
# E-mail 3 processado com sucesso.
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 7042.99ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 7546.38ms
# E-mail 4 processado com sucesso.
# E-mail 5 processado com sucesso.
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 557.38ms
# Erro ao processar o e-mail 6: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash
# Please retry in 8.636210725s.
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 633.13ms
# Erro ao processar o e-mail 7: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash
# Please retry in 7.956138969s.
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 532.99ms
# Erro ao processar o e-mail 8: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash
# Please retry in 7.400410517s.
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 660.70ms
# Erro ao processar o e-mail 9: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash
# Please retry in 6.786511667s.
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 688.31ms
# Erro ao processar o e-mail 10: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash
# Please retry in 6.158506492s.
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 635.30ms
# Erro ao processar o e-mail 11: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash
# Please retry in 5.420008728s.
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 787.26ms
# Erro ao processar o e-mail 12: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash
# Please retry in 4.745154606s.
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 509.47ms
# Erro ao processar o e-mail 13: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash
# Please retry in 4.105546694s.
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 686.02ms
# Erro ao processar o e-mail 14: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash
# Please retry in 3.433071946s.
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 559.26ms
# Erro ao processar o e-mail 15: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash
# Please retry in 2.90432422s.
# E-mail 16 processado com sucesso.
# E-mail 17 processado com sucesso.
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 511.23ms
# Erro ao processar o e-mail 18: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash
# Please retry in 52.361319207s.
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 766.90ms
# Erro ao processar o e-mail 19: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash
# Please retry in 51.688192766s.
# WARNING:tornado.access:429 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 557.86ms
# Erro ao processar o e-mail 20: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash
# Please retry in 50.989058692s.
#
# --- RESULTADOS ---
# • Agendar uma reunião de alinhamento para discutir resultados e planejar próximos passos.
# • Convidar o pessoal para celebrar as metas batidas.
# • Comunicar a atualização das diretrizes de trabalho remoto.
# • Quer o livro emprestado de volta.
# • O remetente deseja parabenizar a equipe pela qualidade do trabalho e apresentar pontos de ajuste.
# • Erro ao gerar resumo.
# • Erro ao gerar resumo.
# • Erro ao gerar resumo.
# • Erro ao gerar resumo.
# • Erro ao gerar resumo.
# • Erro ao gerar resumo.
# • Erro ao gerar resumo.
# • Erro ao gerar resumo.
# • Erro ao gerar resumo.
# • Erro ao gerar resumo.
# • O remetente solicita um teste remoto na linha para resolver a conexão instável.
# • Boas-vindas e indicação de próximos passos para o novo colaborador.
# • Erro ao gerar resumo.
# • Erro ao gerar resumo.
# • Erro ao gerar resumo.
